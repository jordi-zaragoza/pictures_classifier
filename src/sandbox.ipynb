# %%
import lib.blurr_lib
import tensorflow as tf
import lib.picture_lib
import lib.model_lib
import lib.profile_lib
import os

# %%
image = tf.keras.preprocessing.image.load_img('../data/work/boda_anna_carles/01_Firma/pictures/faces/3V9A3563_5.jpg')
image = tf.keras.preprocessing.image.img_to_array(image)

# %%
model_profile = lib.model_lib.load_model('model_profile')

# %%
profile = not lib.model_lib.predict(image, model_profile, True, sure_rate=0.9)
# Out:
# Predictions:
#  [0.00019646]

# %%
profile
# Out:
# True

# %%
path = '../data/test'
image_list = os.listdir(path)

# %%
for image_name in image_list:
    image = tf.keras.preprocessing.image.load_img(path+'/'+image_name)
    image = tf.keras.preprocessing.image.img_to_array(image)
    lib.blurr_lib.is_blurry(image, model_blurry, True, sure_rate=0.9)
# Out:
# Predictions:
#  [0.7166107]
# Predictions:
#  [0.430671]
# Predictions:
#  [0.766199]
# Predictions:
#  [0.39406076]
# Predictions:
#  [0.9891711]
# Predictions:
#  [0.63233775]
# Predictions:
#  [0.46050122]
# Predictions:
#  [0.8922867]
# Predictions:
#  [0.9453513]
# Predictions:
#  [0.34936887]
# Predictions:
#  [0.10220777]
# Predictions:
#  [0.8334047]
# Predictions:
#  [0.04834769]
# Predictions:
#  [0.44556454]
# Predictions:
#  [0.5736453]
# Predictions:
#  [0.33149123]
# Predictions:
#  [0.70616144]
# Predictions:
#  [0.02687842]
# Predictions:
#  [0.93825716]
# Predictions:
#  [0.8098697]
# Predictions:
#  [0.865062]
# Predictions:
#  [0.61840063]
# Predictions:
#  [0.8720613]
# ...
